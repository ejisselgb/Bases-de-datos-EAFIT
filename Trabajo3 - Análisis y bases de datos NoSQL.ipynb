# %% [markdown]
# # Definición del trabajo
#
# Teniendo en cuenta todo lo aprendido en clase, vamos a migrar nuestra estructura de base de datos relacional a NoSQL.
#
# Para lograr esto, vamos a tomar los diagramas iniciales el Modelo Entidad Relación, el Modelo Relacional y vamos a identificar que problemas y errores tienen estos en base a lo aprendido. Luego procederemos a construir la migración de nuestro modelo con el fin de facilitar la replicación, la consulta de datos (recuerda que nuestro sitio web es de películas y hay personas de todo el mundo haciendo constantes consultas), agilidad en la lectura y escalabilidad.
#
# A partir de los diagramas anteriormente nombrados construye un modelo de datos con la siguiente estructura. El archivo adjunto puede ser de formato JSON o .txt.
#
# Formato archivo para base de datos NoSQL:
#
# ![Screenshot_213.png](attachment:Screenshot_213.png)
#
# Crea las estructuras que sean necesarias. Recuerda que puedes referenciar documentos o tablas usando un id único.
#
# No utilices un documento para guardar toda la información.
#
# Luego, crea tu base de datos (Dynamo o MongoDB) con la información creada, al menos 3 registros por cada tabla o documento.
#
# - Inserta la información usando las consultas vistas en clase o en la guía, NO DE MANERA MANUAL.
# - Edita, elimina y selecciona elementos de tu base de datos utilizando las consultas vistas en clase.
# - En el caso de Dynamo las consultas pueden ser directamente sobre la consola o utilizando scripts de Python, ambas son válidas.
# - Para el caso de MongoDB las consultas pueden ser directamente sobre la consola.
# - Crea una presentación que te permita indicar el mayor desafío de migrar bases de datos de un modelo a otro.
# - ¿Qué base de datos prefieres y por qué?.
# - Ventajas y desventajas que identificas en la base de datos de tu sitio web de películas.
# - ¿Qué área de las bases de datos te gustaría enfatizar y por qué?
#
# Consultas de selección:
# - Seleccionar todas las películas que fueron estrenadas después del 2017
# - Seleccionar los autores de solo una película, buscar y mostrar en que otras películas han trabajado esos autores
# - Seleccionar los comentarios de una película que tengan calificación por debajo o iguale3
# - Seleccionar los comentarios de una película que tengan una califiación por encima de 3

# %% [markdown]
# ### Entrega del trabajo
#
# - 10 de junio de 2022 vía GITHUB. Crear una carpeta nueva llamada: Trabajo 3, NoSQL Movies
# - Hora Maxima de entrega 04:30 pm.
# - La sustentación será virtual y el espacio abierto será desde las 1:30 pm hasta las 4:30pm (https://calendly.com/erika-giselle-gb/sustentacion-trabajo-final?month=2022-06&date=2022-06-10).
# - Se deben encender las cámaras para la sustentación, NO se permite sustentar con cámara apagada.
# - El ambiente deberá montarse de manera local, si desea explorar con AWS, puede utilizar las credenciales habilitadas previamente, recuerde no subir estas en el GITHUB.
# - Si desea crear lambdas de prueba notificar al menos con tres días de anticipación para crear una llamada un habilitar las funciones a través del código creado por ustedes.
# - Pueden escoger la base de datos que los haga sentir más cómodos, Dynamo o MongoDB

# %% [markdown]
# **¡Muchos éxitos en esta entrega final, les irá igual de bien como en todas las demás!**
