# %% [markdown]
# # Clase 17 - Maratón de programación para bases de datos
#
#
# En esta práctica estudiaremos conceptos vistos en clase de normalización, consultas SQL, JOINS y algebra relacional.
# Los puntos obtenidos en esta práctica sumarán puntos para el parcial 2 el cual se realizará el día viernes 8 de abril de 2022.
#
# Los puntos serán distribuidos de la siguiente manera:
#
# - Ejercicio de normalización, globo morado (0.1)
# - Ejercicios de consultas INNER JOIN, globo verde (0.15)
# - Ejercicios de consulta con LEFT JOIN - RIGHT JOIN, globo amarillo (0.15)
# - Ejercicios de consultas usando JOIN + 3 tablas, globo azul (0.2)
# - Ejercicios de consulta con algebra relacional UNION, producto cartesiano, theta select, projection. Globo naranja (0.17)

# %% [markdown]
# ## INSTRUCCIONES
#
# Lea detalladamente las instrucciones que aquí se indican, para así, evitar inconvenientes y no afectar los puntos ganados. Los ejercicios deben contar con las características que aquí se definen.
#
# 1. Para los ejercicios de normalización es importante presentar un esquema puede ser en papel, pero se vale el punto siempre y cuando las tablas estén creadas en la BD y tengan todas las relaciones esperadas.
# 2. La estructura de las tablas debe ser MBD_nombre de su tabla (MBD indica maratón Bases de Datos)
# 3. Todos los nombres de las tablas deben ser en mayuscula y deben ser separadas las palabras por un guión bajo.
# 4. Las tablas deben estar construidas en plural.
# 5. Los nombres de los atributos deben estar en minúscula, separados por guión bajo y en singular.
# 6. Los nombres de los atributos deben ser claros y deben estar relacionados al nombre de la tabla.
# 7. Las tablas deben existir unicamente en su esquema.

# %% [markdown]
# ### Ejercicio normalización, globo morado
#
# Dada la información que se muestra en la siguiente tabla, normalice la información de manera que obtenga las tablas
# - Pasajero
# - Conductor
# - Viaje
# - Pago
# - Vehículo

# %% [markdown]
# ![Screenshot_178.png](attachment:Screenshot_178.png)

# %% [markdown]
# - Es importante agregar información que en la tabla a normalizar no se encuentra como lo es número de teléfono tanto del pasajero como del conductor.
# - Es necesario en las consultas conocer la fecha de registro del conductor, valida si en los datos de la base de datos sin normalizar existe este campo, de lo contrario agregalo.
# - Agregar el país al pasajero (ya que de esta manera el sistema filtrará los conductores por país y mostrará solo información al país seleccionado por el pasajero)
# - Recuerde crear relaciones por ID y no por nombre del conductor o pasajero. Aplique esto para todas las tablas, cree un ID para cada una de ellas.
# - No utilice caracteres especiales en la creación de las tablas o columnas.
# - Cuando cree la información del pago, si el método utilizado es efectivo, el número de tarjeta de crédito a insertar es 0.
# - Valide si al normalizar es posible obtener la información de la fecha de viaje. Si no cuenta con dicha información agreguela.
# - El tipo de dato para fecha inicio y fin del viaje es time.
# - Almacene el tiempo de espera como entero, no hay problema ya que no se está pidiendo algún cálculo para obtener el tiempo de espera exacto mientras el pasajero toma el servicio que ha llegado a la dirección origen.
# - Para el país almacene únicamente las siglas CO, ES BR, etc.
# - Puede saltarse este paso pidiendo el script, sin embargo, ya no será valido este punto.
# - Los inserts los encontrarás en interactiva

# %% [markdown]
# ### Ejercicios INNER JOIN, globo verde
#
# - Agregue tres nuevos pasajeros a la base de datos, no los relacione con ningún viaje, pues la fecha de creación debe ser la actual o la del día de hoy.
# - Agregue dos nuevos conductores a la base de datos, no los relacione con ningún viaje, pues la fecha de creación debe ser la actual o la del día de hoy.
# - Cree una consulta de manera que, le permita identificar todos los conductores que han realizado al menos una viaje a la fecha.

# %% [markdown]
# ### Ejercicios LEFT JOIN - RIGHT JOIN, globo amarillo
#
# - Cree una consulta que le permita obtener la información de conductores que no han realizado ningún viaje y el año de registro sea 2020, haga uso de  `where extract(year from fecha_viaje) = 2020`;
# - Cree una consulta de forma que le permita obtener la información de todos los viajes realizados hasta el momento y los usuarios que no han realizado ningpun tipo de viaje. (Pidale al profesor que valide con usted este punto)
# - Cree un viaje nuevo para los usuario que no han realizado ningún viaje, seleccione uno de los nuevos conductores para hacer los viajes, deben estar en horas distintas, puede ser la misma fecha.

# %% [markdown]
# ### Ejercicios JOIN +3 TABLAS, globo azul
#
# - Cree una consulta que le permita obtener la información del conductor y el pago de un viaje, para así saber más o menos cuanto le deberán pagar al usuario.
# - Ahora la consulta realizada con las tres tablas en el SELECT donde se agregan los campos (antes del from) muestre solo el nombre del conductor y adicionalmente agregue COUNT(co.nombre_completo) (co es el alias de la tabla conductores). Al final de la consulta agregue group by co.nombre_completo, recuerde reemplazar el alias por el que usted creo previamente.

# %% [markdown]
# ### Ejemplos de consultas algebra relacional, globo naranja
#
# - Cree una consulta que le permita obtener toda la información personal como nombre completo, y telefono de los conductores y los pasajeros.
# - Cree una consulta donde sea posible obtener la información del pasajero y los viajes de todos aquellos usuarios con edades inferiores a los 25 años.
# - Cree una consulta para obtener una única vez los id de los conductores, sin duplicados, esto permitira
